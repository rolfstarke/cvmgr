# %% [markdown]
# # Convert Dataset Formats
#
# This recipe demonstrates how to use FiftyOne to convert datasets on disk between common formats.

# %% [markdown]
# ## Setup

# %% [markdown]
# If you haven't already, install FiftyOne:

# %%
pip install fiftyone
# Out:
# Requirement already satisfied: fiftyone in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (1.7.0)
# Requirement already satisfied: aiofiles in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (24.1.0)
# Requirement already satisfied: argcomplete in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (3.6.2)
# Requirement already satisfied: async_lru>=2 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (2.0.5)
# Requirement already satisfied: beautifulsoup4 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (4.13.4)
# Requirement already satisfied: boto3 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (1.39.1)
# Requirement already satisfied: cachetools in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (6.1.0)
# Requirement already satisfied: dacite<1.8.0,>=1.6.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (1.7.0)
# Requirement already satisfied: dill in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (0.4.0)
# Requirement already satisfied: Deprecated in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (1.2.18)
# Requirement already satisfied: ftfy in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (6.3.1)
# Requirement already satisfied: humanize in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (4.12.3)
# Requirement already satisfied: hypercorn>=0.13.2 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (0.17.3)
# Requirement already satisfied: Jinja2>=3 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (3.1.6)
# Requirement already satisfied: kaleido!=0.2.1.post1 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (1.0.0)
# Requirement already satisfied: matplotlib in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (3.10.3)
# Requirement already satisfied: mongoengine~=0.29.1 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (0.29.1)
# Requirement already satisfied: motor~=3.6.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (3.6.1)
# Requirement already satisfied: numpy in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (2.2.6)
# Requirement already satisfied: packaging in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (25.0)
# Requirement already satisfied: pandas in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (2.3.0)
# Requirement already satisfied: Pillow>=6.2 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (11.3.0)
# Requirement already satisfied: plotly>=4.14 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (6.2.0)
# Requirement already satisfied: pprintpp in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (0.4.0)
# Requirement already satisfied: psutil in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (5.9.1)
# Requirement already satisfied: pymongo~=4.9.2 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (4.9.2)
# Requirement already satisfied: pytz in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (2025.2)
# Requirement already satisfied: PyYAML in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (6.0.2)
# Requirement already satisfied: regex in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (2024.11.6)
# Requirement already satisfied: retrying in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (1.4.0)
# Requirement already satisfied: rtree in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (1.4.0)
# Requirement already satisfied: scikit-learn in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (1.7.0)
# Requirement already satisfied: scikit-image in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (0.25.2)
# Requirement already satisfied: scipy in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (1.15.3)
# Requirement already satisfied: setuptools in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (78.1.1)
# Requirement already satisfied: sseclient-py<2,>=1.7.2 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (1.8.0)
# Requirement already satisfied: sse-starlette<1,>=0.10.3 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (0.10.3)
# Requirement already satisfied: starlette>=0.24.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (0.47.1)
# Requirement already satisfied: strawberry-graphql>=0.262.4 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (0.275.5)
# Requirement already satisfied: tabulate in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (0.9.0)
# Requirement already satisfied: tqdm in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (4.67.1)
# Requirement already satisfied: xmltodict in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (0.14.2)
# Requirement already satisfied: universal-analytics-python3<2,>=1.0.1 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (1.1.1)
# Requirement already satisfied: pydash in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (8.0.5)
# Requirement already satisfied: fiftyone-brain<0.22,>=0.21.2 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (0.21.2)
# Requirement already satisfied: fiftyone-db<2.0,>=0.4 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (1.3.0)
# Requirement already satisfied: voxel51-eta<0.15,>=0.14.2 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (0.14.2)
# Requirement already satisfied: opencv-python-headless in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from fiftyone) (4.10.0.84)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from pymongo~=4.9.2->fiftyone) (2.7.0)
# Requirement already satisfied: httpx>=0.10.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from universal-analytics-python3<2,>=1.0.1->fiftyone) (0.28.1)
# Requirement already satisfied: future in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from voxel51-eta<0.15,>=0.14.2->fiftyone) (1.0.0)
# Requirement already satisfied: glob2 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from voxel51-eta<0.15,>=0.14.2->fiftyone) (0.7)
# Requirement already satisfied: jsonlines in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from voxel51-eta<0.15,>=0.14.2->fiftyone) (4.0.0)
# Requirement already satisfied: py7zr in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from voxel51-eta<0.15,>=0.14.2->fiftyone) (1.0.0)
# Requirement already satisfied: python-dateutil in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from voxel51-eta<0.15,>=0.14.2->fiftyone) (2.9.0.post0)
# Requirement already satisfied: rarfile in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from voxel51-eta<0.15,>=0.14.2->fiftyone) (4.2)
# Requirement already satisfied: requests in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from voxel51-eta<0.15,>=0.14.2->fiftyone) (2.32.4)
# Requirement already satisfied: six in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from voxel51-eta<0.15,>=0.14.2->fiftyone) (1.17.0)
# Requirement already satisfied: sortedcontainers in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from voxel51-eta<0.15,>=0.14.2->fiftyone) (2.4.0)
# Requirement already satisfied: tzlocal in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from voxel51-eta<0.15,>=0.14.2->fiftyone) (5.3.1)
# Requirement already satisfied: urllib3 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from voxel51-eta<0.15,>=0.14.2->fiftyone) (2.5.0)
# Requirement already satisfied: typing_extensions>=4.0.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from async_lru>=2->fiftyone) (4.14.0)
# Requirement already satisfied: anyio in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone) (4.9.0)
# Requirement already satisfied: certifi in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone) (1.0.9)
# Requirement already satisfied: idna in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone) (3.7)
# Requirement already satisfied: h11>=0.16 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone) (0.16.0)
# Requirement already satisfied: exceptiongroup>=1.1.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from hypercorn>=0.13.2->fiftyone) (1.3.0)
# Requirement already satisfied: h2>=3.1.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from hypercorn>=0.13.2->fiftyone) (4.2.0)
# Requirement already satisfied: priority in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from hypercorn>=0.13.2->fiftyone) (2.0.0)
# Requirement already satisfied: taskgroup in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from hypercorn>=0.13.2->fiftyone) (0.2.2)
# Requirement already satisfied: tomli in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from hypercorn>=0.13.2->fiftyone) (2.2.1)
# Requirement already satisfied: wsproto>=0.14.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from hypercorn>=0.13.2->fiftyone) (1.2.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from h2>=3.1.0->hypercorn>=0.13.2->fiftyone) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from h2>=3.1.0->hypercorn>=0.13.2->fiftyone) (4.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from Jinja2>=3->fiftyone) (3.0.2)
# Requirement already satisfied: choreographer>=1.0.5 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from kaleido!=0.2.1.post1->fiftyone) (1.0.9)
# Requirement already satisfied: logistro>=1.0.8 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from kaleido!=0.2.1.post1->fiftyone) (1.1.0)
# Requirement already satisfied: orjson>=3.10.15 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from kaleido!=0.2.1.post1->fiftyone) (3.10.18)
# Requirement already satisfied: simplejson>=3.19.3 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from choreographer>=1.0.5->kaleido!=0.2.1.post1->fiftyone) (3.20.1)
# Requirement already satisfied: narwhals>=1.15.1 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from plotly>=4.14->fiftyone) (1.45.0)
# Requirement already satisfied: sniffio>=1.1 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from anyio->httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone) (1.3.1)
# Requirement already satisfied: graphql-core<3.4.0,>=3.2.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from strawberry-graphql>=0.262.4->fiftyone) (3.2.6)
# Requirement already satisfied: soupsieve>1.2 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from beautifulsoup4->fiftyone) (2.7)
# Requirement already satisfied: botocore<1.40.0,>=1.39.1 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from boto3->fiftyone) (1.39.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from boto3->fiftyone) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from boto3->fiftyone) (0.13.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from Deprecated->fiftyone) (1.17.2)
# Requirement already satisfied: wcwidth in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from ftfy->fiftyone) (0.2.13)
# Requirement already satisfied: attrs>=19.2.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from jsonlines->voxel51-eta<0.15,>=0.14.2->fiftyone) (25.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from matplotlib->fiftyone) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from matplotlib->fiftyone) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from matplotlib->fiftyone) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from matplotlib->fiftyone) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from matplotlib->fiftyone) (3.2.3)
# Requirement already satisfied: tzdata>=2022.7 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from pandas->fiftyone) (2025.2)
# Requirement already satisfied: texttable in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone) (1.7.0)
# Requirement already satisfied: pycryptodomex>=3.20.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone) (3.23.0)
# Requirement already satisfied: brotli>=1.1.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone) (1.1.0)
# Requirement already satisfied: pyzstd>=0.16.1 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone) (0.17.0)
# Requirement already satisfied: pyppmd<1.3.0,>=1.1.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone) (1.2.0)
# Requirement already satisfied: pybcj<1.1.0,>=1.0.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone) (1.0.6)
# Requirement already satisfied: multivolumefile>=0.2.3 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone) (0.2.3)
# Requirement already satisfied: inflate64<1.1.0,>=1.0.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone) (1.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from requests->voxel51-eta<0.15,>=0.14.2->fiftyone) (3.4.2)
# Requirement already satisfied: networkx>=3.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from scikit-image->fiftyone) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from scikit-image->fiftyone) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from scikit-image->fiftyone) (2025.5.10)
# Requirement already satisfied: lazy-loader>=0.4 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from scikit-image->fiftyone) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from scikit-learn->fiftyone) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from scikit-learn->fiftyone) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# This notebook contains bash commands. To run it as a notebook, you must install the [Jupyter bash kernel](https://github.com/takluyver/bash_kernel) via the command below.
#
# Alternatively, you can just copy + paste the code blocks into your shell.

# %%
pip install bash_kernel
python -m bash_kernel.install
# Out:
#   Cell In[10], line 1
#     pip install bash_kernel
#         ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# In this recipe we'll use the [FiftyOne Dataset Zoo](https://docs.voxel51.com/dataset_zoo/index.html) to download some open source datasets to work with.
#
# Specifically, we'll need [TensorFlow](https://www.tensorflow.org/) and [TensorFlow Datasets](https://www.tensorflow.org/datasets) installed to [access the datasets](https://docs.voxel51.com/dataset_zoo/api.html#customizing-your-ml-backend):

# %%
pip install tensorflow tensorflow-datasets
# Out:
# Requirement already satisfied: tensorflow in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (2.19.0)
# Requirement already satisfied: tensorflow-datasets in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (4.9.9)
# Requirement already satisfied: absl-py>=1.0.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow) (25.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow)
#   Using cached protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow) (78.1.1)
# Requirement already satisfied: six>=1.12.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow) (1.73.1)
# Requirement already satisfied: tensorboard~=2.19.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: array_record>=0.5.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow-datasets) (0.7.2)
# Requirement already satisfied: dm-tree in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow-datasets) (0.1.9)
# Requirement already satisfied: etils>=1.6.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets) (1.12.2)
# Requirement already satisfied: immutabledict in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow-datasets) (4.2.1)
# Requirement already satisfied: promise in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow-datasets) (2.3)
# Requirement already satisfied: psutil in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow-datasets) (5.9.1)
# Requirement already satisfied: pyarrow in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow-datasets) (18.1.0)
# Requirement already satisfied: simple_parsing in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow-datasets) (0.1.7)
# Requirement already satisfied: tensorflow-metadata in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow-datasets) (1.17.2)
# Requirement already satisfied: toml in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow-datasets) (0.10.2)
# Requirement already satisfied: tqdm in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from tensorflow-datasets) (4.67.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: einops in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets) (0.8.1)
# Requirement already satisfied: fsspec in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets) (2025.5.1)
# Requirement already satisfied: importlib_resources in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets) (6.5.2)
# Requirement already satisfied: zipp in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets) (3.23.0)
# Requirement already satisfied: rich in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: attrs>=18.2.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from dm-tree->tensorflow-datasets) (25.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /home/freeze/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages (from simple_parsing->tensorflow-datasets) (0.16)
#   Using cached protobuf-4.21.12-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Using cached protobuf-4.21.12-cp37-abi3-manylinux2014_x86_64.whl (409 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.31.1
#     Uninstalling protobuf-6.31.1:
#       Successfully uninstalled protobuf-6.31.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.73.1 requires protobuf<7.0.0,>=6.30.0, but you have protobuf 4.21.12 which is incompatible.
# Successfully installed protobuf-4.21.12
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall tensorflow tensorflow-datasets -y
# Out:
# Found existing installation: tensorflow 2.19.0
# Uninstalling tensorflow-2.19.0:
#   Successfully uninstalled tensorflow-2.19.0
# Found existing installation: tensorflow-datasets 4.9.9
# Uninstalling tensorflow-datasets-4.9.9:
#   Successfully uninstalled tensorflow-datasets-4.9.9
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Download datasets

# %% [markdown]
# Download the test split of the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html) from the [FiftyOne Dataset Zoo](https://docs.voxel51.com/dataset_zoo/index.html) using the command below:

# %%
# Download the test split of CIFAR-10
fiftyone zoo datasets download c ifar10--split test
# Out:
#   Cell In[13], line 2
#     fiftyone zoo datasets download c ifar10--split test
#                                            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# Download the validation split of the [KITTI dataset]( http://www.cvlibs.net/datasets/kitti) from the [FiftyOne Dataset Zoo](https://docs.voxel51.com/dataset_zoo/index.html) using the command below:

# %%
# Download the validation split of KITTI
fiftyone zoo datasets download kitti --split validation
# Out:
# Split 'validation' already downloaded

# %% [markdown]
# ## The fiftyone convert command

# %% [markdown]
# The [FiftyOne CLI](https://voxel51.com/docs/fiftyone/cli/index.html) provides a number of utilities for importing and exporting datasets in a variety of common (or custom) formats.
#
# Specifically, the `fiftyone convert` command provides a convenient way to convert datasets on disk between formats by specifying the [fiftyone.types.Dataset](https://voxel51.com/docs/fiftyone/api/fiftyone.types.html#fiftyone.types.dataset_types.Dataset) type of the input and desired output.
#
# FiftyOne provides a collection of [builtin types](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#supported-import-formats) that you can use to read/write datasets in common formats out-of-the-box:

# %% [markdown]
# <div class="convert-recipes-table">
#
# | Dataset format                                                                                                                                   | Import Supported? | Export Supported? | Conversion Supported? |
# | ------------------------------------------------------------------------------------------------------------------------------------------------ | ----------------- | ----------------- | --------------------- |
# | [Image Directory](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#ImageDirectory-import)                                       | ✓                 | ✓                 | ✓                     |
# | [Video Directory](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#VideoDirectory-import)                                       | ✓                 | ✓                 | ✓                     |
# | [Media Directory](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#MediaDirectory-import)                                       | ✓                 | ✓                 | ✓                     |
# | [Image Classification Directory Tree](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#ImageClassificationDirectoryTree-import) | ✓                 | ✓                 | ✓                     |
# | [FiftyOne Image Classification](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#FiftyOneImageClassificationDataset-import)     | ✓                 | ✓                 | ✓                     |
# | [TF Image Classification](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#TFImageClassificationDataset-import)                 | ✓                 | ✓                 | ✓                     |
# | [COCO](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#COCODetectionDataset-import)                                            | ✓                 | ✓                 | ✓                     |
# | [VOC](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#VOCDetectionDataset-import)                                              | ✓                 | ✓                 | ✓                     |
# | [KITTI](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#KITTIDetectionDataset-import)                                          | ✓                 | ✓                 | ✓                     |
# | [YOLOv4](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#YOLOv4Dataset-import)                                                 | ✓                 | ✓                 | ✓                     |
# | [YOLOv5](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#YOLOv5Dataset-import)                                                 | ✓                 | ✓                 | ✓                     |
# | [FiftyOne Object Detection](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#FiftyOneImageDetectionDataset-import)              | ✓                 | ✓                 | ✓                     |
# | [FiftyOne Temporal Detection](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#FiftyOneTemporalDetectionDataset-import)         | ✓                 | ✓                 | ✓                     |
# | [TF Object Detection](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#TFObjectDetectionDataset-import)                         | ✓                 | ✓                 | ✓                     |
# | [Image Segmentation Directory](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#ImageSegmentationDirectory-import)              | ✓                 | ✓                 | ✓                     |
# | [CVAT Image](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#CVATImageDataset-import)                                          | ✓                 | ✓                 | ✓                     |
# | [CVAT Video](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#CVATVideoDataset-import)                                          | ✓                 | ✓                 | ✓                     |
# | [OpenLABEL Image](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#OpenLABELImageDataset-import)                                | ✓                 |                   |                       |
# | [OpenLABEL Video](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#OpenLABELVideoDataset-import)                                | ✓                 |                   |                       |
# | [BDD](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#BDDDataset-import)                                                       | ✓                 | ✓                 | ✓                     |
# | [CSV](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#CSVDataset-import)                                                       | ✓                 | ✓                 | ✓                     |
# | [DICOM](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#DICOMDataset-import)                                                   | ✓                 | ✓                 | ✓                     |
# | [GeoJSON](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#GeoJSONDataset-import)                                               | ✓                 | ✓                 | ✓                     |
# | [GeoTIFF](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#GeoTIFFDataset-import)                                               | ✓                 |                   |                       |
# | [FiftyOne Dataset](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#FiftyOneDataset-import)                                     | ✓                 | ✓                 | ✓                     |
# | [FiftyOne Image Labels](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#FiftyOneImageLabelsDataset-import)                     | ✓                 | ✓                 | ✓                     |
# | [FiftyOne Video Labels](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#FiftyOneVideoLabelsDataset-import)                     | ✓                 | ✓                 | ✓                     |
#
# </div>

# %% [markdown]
# In addition, you can define your own [custom dataset types](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#custom-dataset-importer) to read/write datasets in your own formats.
#
# The usage of the `fiftyone convert` command is as follows:

# %%
fiftyone convert -h
# Out:
# usage: fiftyone convert [-h] --input-type INPUT_TYPE --output-type OUTPUT_TYPE
#                         [--input-dir INPUT_DIR]
#                         [--input-kwargs KEY=VAL [KEY=VAL ...]]
#                         [--output-dir OUTPUT_DIR]
#                         [--output-kwargs KEY=VAL [KEY=VAL ...]] [-o]
#
# Convert datasets on disk between supported formats.
#
#     Examples::
#
#         # Convert an image classification directory tree to TFRecords format
#         fiftyone convert \
#             --input-dir /path/to/image-classification-directory-tree \
#             --input-type fiftyone.types.ImageClassificationDirectoryTree \
#             --output-dir /path/for/tf-image-classification-dataset \
#             --output-type fiftyone.types.TFImageClassificationDataset
#
#         # Convert a COCO detection dataset to CVAT image format
#         fiftyone convert \
#             --input-dir /path/to/coco-detection-dataset \
#             --input-type fiftyone.types.COCODetectionDataset \
#             --output-dir /path/for/cvat-image-dataset \
#             --output-type fiftyone.types.CVATImageDataset
#
#         # Perform a customized conversion via optional kwargs
#         fiftyone convert \
#             --input-dir /path/to/coco-detection-dataset \
#             --input-type fiftyone.types.COCODetectionDataset \
#             --input-kwargs max_samples=100 shuffle=True \
#             --output-dir /path/for/cvat-image-dataset \
#             --output-type fiftyone.types.TFObjectDetectionDataset \
#             --output-kwargs force_rgb=True \
#             --overwrite
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --input-dir INPUT_DIR
#                         the directory containing the dataset
#   --input-kwargs KEY=VAL [KEY=VAL ...]
#                         additional keyword arguments for `fiftyone.utils.data.convert_dataset(..., input_kwargs=)`
#   --output-dir OUTPUT_DIR
#                         the directory to which to write the output dataset
#   --output-kwargs KEY=VAL [KEY=VAL ...]
#                         additional keyword arguments for `fiftyone.utils.data.convert_dataset(..., output_kwargs=)`
#   -o, --overwrite       whether to overwrite an existing output directory
#
# required arguments:
#   --input-type INPUT_TYPE
#                         the fiftyone.types.Dataset type of the input dataset
#   --output-type OUTPUT_TYPE
#                         the fiftyone.types.Dataset type to output

# %% [markdown]
# ## Convert CIFAR-10 dataset

# %% [markdown]
# When you downloaded the test split of the CIFAR-10 dataset above, it was written to disk as a dataset in [fiftyone.types.FiftyOneImageClassificationDataset](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#FiftyOneImageClassificationDataset-import) format.
#
# You can verify this by printing information about the downloaded dataset:

# %%
fiftyone zoo datasets info cifar10
# Out:
# ***** Dataset description *****
# The CIFAR-10 dataset consists of 60000 32 x 32 color images in 10
#     classes, with 6000 images per class. There are 50000 training images and
#     10000 test images.
#
#     Dataset size:
#         132.40 MiB
#
#     Source:
#         https://www.cs.toronto.edu/~kriz/cifar.html
#
# ***** Supported splits *****
# test, train
#
# ***** Dataset location *****
# ~/fiftyone/cifar10
#
# ***** Dataset info *****
# {
#     "name": "cifar10",
#     "zoo_dataset": "fiftyone.zoo.datasets.torch.CIFAR10Dataset",
#     "dataset_type": "fiftyone.types.dataset_types.FiftyOneImageClassificationDataset",
#     "num_samples": 10000,
#     "downloaded_splits": {
#         "test": {
#             "split": "test",
#             "num_samples": 10000
#         }
#     },
#     "classes": [
#         "airplane",
#         "automobile",
#         "bird",
#         "cat",
#         "deer",
#         "dog",
#         "frog",
#         "horse",
#         "ship",
#         "truck"
#     ]
# }

# %% [markdown]
# The snippet below uses `fiftyone convert` to convert the test split of the CIFAR-10 dataset to [fiftyone.types.ImageClassificationDirectoryTree](https://voxel51.com/docs/fiftyone/user_guide/export_datasets.html#imageclassificationdirectorytree) format, which stores classification datasets on disk in a directory tree structure with images organized per-class:
#
# ```
# <dataset_dir>
# ├── <classA>/
# │   ├── <image1>.<ext>
# │   ├── <image2>.<ext>
# │   └── ...
# ├── <classB>/
# │   ├── <image1>.<ext>
# │   ├── <image2>.<ext>
# │   └── ...
# └── ...
# ```

# %%
INPUT_DIR=$(fiftyone zoo datasets find cifar10 --split test)
OUTPUT_DIR=/tmp/fiftyone/cifar10-dir-tree

fiftyone convert \
    --input-dir ${INPUT_DIR} --input-type fiftyone.types.FiftyOneImageClassificationDataset \
    --output-dir ${OUTPUT_DIR} --output-type fiftyone.types.ImageClassificationDirectoryTree
# Out:
# Loading dataset from '~/fiftyone/cifar10/test'
# Input format 'fiftyone.types.dataset_types.FiftyOneImageClassificationDataset'
#  100% |███| 10000/10000 [4.2s elapsed, 0s remaining, 2.4K samples/s]
# Import complete
# Exporting dataset to '/tmp/fiftyone/cifar10-dir-tree'
# Export format 'fiftyone.types.dataset_types.ImageClassificationDirectoryTree'
#  100% |███| 10000/10000 [6.2s elapsed, 0s remaining, 1.7K samples/s]
# Export complete

# %% [markdown]
# Let's verify that the conversion happened as expected:

# %%
ls -lah /tmp/fiftyone/cifar10-dir-tree/
# Out:
# total 0
# drwxr-xr-x    12 voxel51  wheel   384B Jul 14 11:08 .
# drwxr-xr-x     3 voxel51  wheel    96B Jul 14 11:08 ..
# drwxr-xr-x  1002 voxel51  wheel    31K Jul 14 11:08 airplane
# drwxr-xr-x  1002 voxel51  wheel    31K Jul 14 11:08 automobile
# drwxr-xr-x  1002 voxel51  wheel    31K Jul 14 11:08 bird
# drwxr-xr-x  1002 voxel51  wheel    31K Jul 14 11:08 cat
# drwxr-xr-x  1002 voxel51  wheel    31K Jul 14 11:08 deer
# drwxr-xr-x  1002 voxel51  wheel    31K Jul 14 11:08 dog
# drwxr-xr-x  1002 voxel51  wheel    31K Jul 14 11:08 frog
# drwxr-xr-x  1002 voxel51  wheel    31K Jul 14 11:08 horse
# drwxr-xr-x  1002 voxel51  wheel    31K Jul 14 11:08 ship
# drwxr-xr-x  1002 voxel51  wheel    31K Jul 14 11:08 truck

# %%
ls -lah /tmp/fiftyone/cifar10-dir-tree/airplane/ | head
# Out:
# total 8000
# drwxr-xr-x  1002 voxel51  wheel    31K Jul 14 11:08 .
# drwxr-xr-x    12 voxel51  wheel   384B Jul 14 11:08 ..
# -rw-r--r--     1 voxel51  wheel   1.2K Jul 14 11:23 000004.jpg
# -rw-r--r--     1 voxel51  wheel   1.1K Jul 14 11:23 000011.jpg
# -rw-r--r--     1 voxel51  wheel   1.1K Jul 14 11:23 000022.jpg
# -rw-r--r--     1 voxel51  wheel   1.3K Jul 14 11:23 000028.jpg
# -rw-r--r--     1 voxel51  wheel   1.2K Jul 14 11:23 000045.jpg
# -rw-r--r--     1 voxel51  wheel   1.2K Jul 14 11:23 000053.jpg
# -rw-r--r--     1 voxel51  wheel   1.3K Jul 14 11:23 000075.jpg

# %% [markdown]
# Now let's convert the classification directory tree to [TFRecords](https://voxel51.com/docs/fiftyone/user_guide/export_datasets.html#tfimageclassificationdataset) format!

# %%
INPUT_DIR=/tmp/fiftyone/cifar10-dir-tree
OUTPUT_DIR=/tmp/fiftyone/cifar10-tfrecords

fiftyone convert \
    --input-dir ${INPUT_DIR} --input-type fiftyone.types.ImageClassificationDirectoryTree \
    --output-dir ${OUTPUT_DIR} --output-type fiftyone.types.TFImageClassificationDataset
# Out:
# Loading dataset from '/tmp/fiftyone/cifar10-dir-tree'
# Input format 'fiftyone.types.dataset_types.ImageClassificationDirectoryTree'
#  100% |███| 10000/10000 [4.0s elapsed, 0s remaining, 2.5K samples/s]
# Import complete
# Exporting dataset to '/tmp/fiftyone/cifar10-tfrecords'
# Export format 'fiftyone.types.dataset_types.TFImageClassificationDataset'
#    0% ||--|     1/10000 [23.2ms elapsed, 3.9m remaining, 43.2 samples/s] 2020-07-14 11:24:15.187387: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-07-14 11:24:15.201384: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f83df428f60 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-07-14 11:24:15.201405: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
#  100% |███| 10000/10000 [8.2s elapsed, 0s remaining, 1.3K samples/s]
# Export complete

# %% [markdown]
# Let's verify that the conversion happened as expected:

# %%
ls -lah /tmp/fiftyone/cifar10-tfrecords
# Out:
# total 29696
# drwxr-xr-x  3 voxel51  wheel    96B Jul 14 11:24 .
# drwxr-xr-x  4 voxel51  wheel   128B Jul 14 11:24 ..
# -rw-r--r--  1 voxel51  wheel    14M Jul 14 11:24 tf.records

# %% [markdown]
# ## Convert KITTI dataset

# %% [markdown]
# When you downloaded the validation split of the KITTI dataset above, it was written to disk as a dataset in [fiftyone.types.FiftyOneImageDetectionDataset](https://voxel51.com/docs/fiftyone/user_guide/import_datasets.html#FiftyOneImageDetectionDataset-import) format.
#
# You can verify this by printing information about the downloaded dataset:

# %%
fiftyone zoo datasets info kitti
# Out:
# ***** Dataset description *****
# KITTI contains a suite of vision tasks built using an autonomous
#     driving platform.
#
#     The full benchmark contains many tasks such as stereo, optical flow, visual
#     odometry, etc. This dataset contains the object detection dataset,
#     including the monocular images and bounding boxes. The dataset contains
#     7481 training images annotated with 3D bounding boxes. A full description
#     of the annotations can be found in the README of the object development kit
#     on the KITTI homepage.
#
#     Dataset size:
#         5.27 GiB
#
#     Source:
#         http://www.cvlibs.net/datasets/kitti
#
# ***** Supported splits *****
# test, train, validation
#
# ***** Dataset location *****
# ~/fiftyone/kitti
#
# ***** Dataset info *****
# {
#     "name": "kitti",
#     "zoo_dataset": "fiftyone.zoo.datasets.tf.KITTIDataset",
#     "dataset_type": "fiftyone.types.dataset_types.FiftyOneImageDetectionDataset",
#     "num_samples": 423,
#     "downloaded_splits": {
#         "validation": {
#             "split": "validation",
#             "num_samples": 423
#         }
#     },
#     "classes": [
#         "Car",
#         "Van",
#         "Truck",
#         "Pedestrian",
#         "Person_sitting",
#         "Cyclist",
#         "Tram",
#         "Misc"
#     ]
# }

# %% [markdown]
# The snippet below uses `fiftyone convert` to convert the test split of the CIFAR-10 dataset to [fiftyone.types.COCODetectionDataset](https://voxel51.com/docs/fiftyone/user_guide/export_datasets.html#cocodetectiondataset) format, which writes the dataset to disk with annotations in [COCO format](https://cocodataset.org/#format-data).

# %%
INPUT_DIR=$(fiftyone zoo datasets find kitti --split validation)
OUTPUT_DIR=/tmp/fiftyone/kitti-coco

fiftyone convert \
    --input-dir ${INPUT_DIR} --input-type fiftyone.types.FiftyOneImageDetectionDataset \
    --output-dir ${OUTPUT_DIR} --output-type fiftyone.types.COCODetectionDataset
# Out:
# Loading dataset from '~/fiftyone/kitti/validation'
# Input format 'fiftyone.types.dataset_types.FiftyOneImageDetectionDataset'
#  100% |███████| 423/423 [1.2s elapsed, 0s remaining, 351.0 samples/s]
# Import complete
# Exporting dataset to '/tmp/fiftyone/kitti-coco'
# Export format 'fiftyone.types.dataset_types.COCODetectionDataset'
#  100% |███████| 423/423 [4.4s elapsed, 0s remaining, 96.1 samples/s]
# Export complete

# %% [markdown]
# Let's verify that the conversion happened as expected:

# %%
ls -lah /tmp/fiftyone/kitti-coco/
# Out:
# total 880
# drwxr-xr-x    4 voxel51  wheel   128B Jul 14 11:24 .
# drwxr-xr-x    5 voxel51  wheel   160B Jul 14 11:24 ..
# drwxr-xr-x  425 voxel51  wheel    13K Jul 14 11:24 data
# -rw-r--r--    1 voxel51  wheel   437K Jul 14 11:24 labels.json

# %%
ls -lah /tmp/fiftyone/kitti-coco/data | head
# Out:
# total 171008
# drwxr-xr-x  425 voxel51  wheel    13K Jul 14 11:24 .
# drwxr-xr-x    4 voxel51  wheel   128B Jul 14 11:24 ..
# -rw-r--r--    1 voxel51  wheel   195K Jul 14 11:24 000001.jpg
# -rw-r--r--    1 voxel51  wheel   191K Jul 14 11:24 000002.jpg
# -rw-r--r--    1 voxel51  wheel   167K Jul 14 11:24 000003.jpg
# -rw-r--r--    1 voxel51  wheel   196K Jul 14 11:24 000004.jpg
# -rw-r--r--    1 voxel51  wheel   224K Jul 14 11:24 000005.jpg
# -rw-r--r--    1 voxel51  wheel   195K Jul 14 11:24 000006.jpg
# -rw-r--r--    1 voxel51  wheel   177K Jul 14 11:24 000007.jpg

# %%
cat /tmp/fiftyone/kitti-coco/labels.json | python -m json.tool 2> /dev/null | head -20
echo "..."
cat /tmp/fiftyone/kitti-coco/labels.json | python -m json.tool 2> /dev/null | tail -20
# Out:
# {
#     "info": {
#         "year": "",
#         "version": "",
#         "description": "Exported from FiftyOne",
#         "contributor": "",
#         "url": "https://voxel51.com/fiftyone",
#         "date_created": "2020-07-14T11:24:40"
#     },
#     "licenses": [],
#     "categories": [
#         {
#             "id": 0,
#             "name": "Car",
#             "supercategory": "none"
#         },
#         {
#             "id": 1,
#             "name": "Cyclist",
#             "supercategory": "none"
# ...
#             "area": 4545.8,
#             "segmentation": null,
#             "iscrowd": 0
#         },
#         {
#             "id": 3196,
#             "image_id": 422,
#             "category_id": 3,
#             "bbox": [
#                 367.2,
#                 107.3,
#                 36.2,
#                 105.2
#             ],
#             "area": 3808.2,
#             "segmentation": null,
#             "iscrowd": 0
#         }
#     ]
# }

# %% [markdown]
# Now let's convert from COCO format to [CVAT Image format](https://voxel51.com/docs/fiftyone/user_guide/export_datasets.html#cvatimageformat) format!

# %%
INPUT_DIR=/tmp/fiftyone/kitti-coco
OUTPUT_DIR=/tmp/fiftyone/kitti-cvat

fiftyone convert \
    --input-dir ${INPUT_DIR} --input-type fiftyone.types.COCODetectionDataset \
    --output-dir ${OUTPUT_DIR} --output-type fiftyone.types.CVATImageDataset
# Out:
# Loading dataset from '/tmp/fiftyone/kitti-coco'
# Input format 'fiftyone.types.dataset_types.COCODetectionDataset'
#  100% |███████| 423/423 [2.0s elapsed, 0s remaining, 206.4 samples/s]
# Import complete
# Exporting dataset to '/tmp/fiftyone/kitti-cvat'
# Export format 'fiftyone.types.dataset_types.CVATImageDataset'
#  100% |███████| 423/423 [1.3s elapsed, 0s remaining, 323.7 samples/s]
# Export complete

# %% [markdown]
# Let's verify that the conversion happened as expected:

# %%
ls -lah /tmp/fiftyone/kitti-cvat
# Out:
# total 584
# drwxr-xr-x    4 voxel51  wheel   128B Jul 14 11:25 .
# drwxr-xr-x    6 voxel51  wheel   192B Jul 14 11:25 ..
# drwxr-xr-x  425 voxel51  wheel    13K Jul 14 11:25 data
# -rw-r--r--    1 voxel51  wheel   289K Jul 14 11:25 labels.xml

# %%
cat /tmp/fiftyone/kitti-cvat/labels.xml | head -20
echo "..."
cat /tmp/fiftyone/kitti-cvat/labels.xml | tail -20
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <annotations>
#     <version>1.1</version>
#     <meta>
#         <task>
#             <size>423</size>
#             <mode>annotation</mode>
#             <labels>
#                 <label>
#                     <name>Car</name>
#                     <attributes>
#                     </attributes>
#                 </label>
#                 <label>
#                     <name>Cyclist</name>
#                     <attributes>
#                     </attributes>
#                 </label>
#                 <label>
#                     <name>Misc</name>
# ...
#         <box label="Pedestrian" xtl="360" ytl="116" xbr="402" ybr="212">
#         </box>
#         <box label="Pedestrian" xtl="396" ytl="120" xbr="430" ybr="212">
#         </box>
#         <box label="Pedestrian" xtl="413" ytl="112" xbr="483" ybr="212">
#         </box>
#         <box label="Pedestrian" xtl="585" ytl="80" xbr="646" ybr="215">
#         </box>
#         <box label="Pedestrian" xtl="635" ytl="94" xbr="688" ybr="212">
#         </box>
#         <box label="Pedestrian" xtl="422" ytl="85" xbr="469" ybr="210">
#         </box>
#         <box label="Pedestrian" xtl="457" ytl="93" xbr="520" ybr="213">
#         </box>
#         <box label="Pedestrian" xtl="505" ytl="101" xbr="548" ybr="206">
#         </box>
#         <box label="Pedestrian" xtl="367" ytl="107" xbr="403" ybr="212">
#         </box>
#
# </annotations>

# %% [markdown]
# ## Cleanup
#
# You can cleanup the files generated by this recipe by running the command below:

# %%
rm -rf /tmp/fiftyone
