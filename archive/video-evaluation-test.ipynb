# %%
from ultralytics import YOLO

# Load a pretrained YOLO11n model
model = YOLO("/mnt/EBI-SHARE/06_Data/labelstudio/models/windows/best.pt")

# Define path to video file
source = "/mnt/EBI-SHARE/06_Data/labelstudio/datasets/evaluation/leuthener_benchmark.mp4"

# Run inference on the source
results = model(source, stream=True)  # generator of Results objects
print(results)
# Out:
# <generator object BasePredictor.stream_inference at 0x7630b70984a0>
