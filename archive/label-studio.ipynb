# %%
label-studio-converter import coco -h  # just print help

label-studio-converter import coco -i /mnt/EBI-SHARE/06_Data/labelstudio/datasets/evaluation/room312_and_leuthener-2/valid/_annotations.coco.json -o /mnt/EBI-SHARE/06_Data/labelstudio/datasets/evaluation/room312_and_leuthener-2/_annotation_labelstudio.json

# %%
from label_studio_converter import Converter

input_coco = "/mnt/EBI-SHARE/06_Data/labelstudio/datasets/evaluation/room312_and_leuthener-2/valid/_annotations.coco.json"
output_ls = "/mnt/EBI-SHARE/06_Data/labelstudio/datasets/evaluation/room312_and_leuthener-2/_annotation_labelstudio.json"

convert_coco_to_ls(
    input_coco,
    output_ls,
    image_root_url=None  # set to your image root URL if needed
)

# %%
from label_studio_converter import Converter

c = Converter("/mnt/EBI-SHARE/06_Data/labelstudio/datasets/evaluation/room312_and_leuthener-2/valid/_annotations.coco.json")
c.convert_to_coco('examples/image_bbox/completions/', 'tmp/output.conll', output_image_dir='tmp/images')

# %%
# !label-studio-converter import yolo \
    -i {destination_path} \
    -o output.json \
    --image-root-url "/valid/images"
