# %%
from ultralytics import YOLO

# Load a pretrained YOLO11n model
model = YOLO("/home/freeze/GIT/onemanstreasure/notebooks/runs/detect/train/weights/best.pt")

# Define path to video file
source = "/home/freeze/GIT/onemanstreasure/datasets/evaluation/leuthener_benchmark.mp4"

# Run inference on the source
results = model(source, stream=True, save=True, project="inference_output", name="312_5_results")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/miniconda3/envs/onemanstreasure/lib/python3.10/site-packages/urllib3/util/connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# ...

# %% [markdown]
# #or this

# %%
from ultralytics import YOLO
import cv2
from IPython.display import display, clear_output
from PIL import Image
import numpy as np

# Load model
model = YOLO("/home/freeze/Downloads/models/windows.pt")

# Path to video file
source = "/home/freeze/GIT/onemanstreasure/datasets/evaluation/leuthener_benchmark.mp4"

# Run inference with streaming
results = model(source, stream=True)

# Iterate through frames
for r in results:
    # Get the annotated frame (numpy array)
    frame = r.plot()

    # Convert to PIL Image for Jupyter display
    img = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

    # Display the image
    clear_output(wait=True)
    display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1200>
# Speed: 1.6ms preprocess, 6.7ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
