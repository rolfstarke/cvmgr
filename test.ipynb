# %%
from ultralytics import YOLO
import yaml
from datetime import datetime

with open("settings.yaml", "r") as f:
    config = yaml.safe_load(f)

datasets=config['DATASET_LOCATIONS']
training_configurations=config['TRAINING_CONFIGURATIONS']

for dataset in datasets:
    print(f"Training on dataset: {dataset}")
    for configuration in training_configurations:
        print(f"Using configuration: {configuration}")
        print(f"Number of epochs: {configuration['epochs']}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       5 with open("settings.yaml", "r") as f:
#       6     config = yaml.safe_load(f)
# ----> 8 datasets={config['DATASET_LOCATIONS']}
#       9 training_configurations={config['TRAINING_CONFIGURATIONS']}
#      11 for dataset in datasets:
#
# TypeError: unhashable type: 'list'
