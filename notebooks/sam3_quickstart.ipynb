# %% [markdown]
# # SAM3 for FiftyOne - Quick Start
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/harpreetsahota204/sam3_images/blob/main/sam3_quickstart.ipynb)
#
# Complete guide to using Meta's SAM3 (Segment Anything Model 3) in FiftyOne.
#
# **Features:**
# - 🎯 Concept Segmentation (text prompts)
# - 🖱️ Visual Segmentation (interactive prompts)
# - 🤖 Automatic Segmentation (no prompts)
# - 🔍 Visual Embeddings (1024-dim)

# %% [markdown]
# ## 1. Installation
#
# SAM3 requires transformers from source (not yet on PyPI):

# %%
# %pip install -q git+https://github.com/huggingface/transformers.git#egg=transformers
# %pip install -q fiftyone torch torchvision huggingface-hub umap-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2. Setup

# %%
import fiftyone as fo
import fiftyone.zoo as foz
import fiftyone.brain as fob
import torch
# Load dataset
fo.delete_dataset("quickstart-200")
dataset = foz.load_zoo_dataset("quickstart", max_samples=200)

# Register SAM3 zoo model
foz.register_zoo_model_source(
    "https://github.com/harpreetsahota204/sam3_images"
)

# Load model
model = foz.load_zoo_model("facebook/sam3")

print(f"✅ Loaded {len(dataset)} samples")

device=torch.cuda.is_available()
print(device
)
# Out:
# Dataset already downloaded
# Loading 'quickstart'
#  100% |█████████████████| 200/200 [4.9s elapsed, 0s remaining, 31.6 samples/s]
# Dataset 'quickstart-200' created
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 15
#      10 foz.register_zoo_model_source(
#      11     "https://github.com/harpreetsahota204/sam3_images"
#      12 )
#      14 # Load model
# ---> 15 model = foz.load_zoo_model("facebook/sam3")
#      17 print(f"✅ Loaded {len(dataset)} samples")
#      19 device=torch.cuda.is_available()
#
# File ~/miniconda3/envs/cvmgr/lib/python3.10/site-packages/fiftyone/zoo/models/__init__.py:312, in load_zoo_model(name_or_url, model_name, download_if_necessary, ensure_requirements, install_requirements, error_level, cache, **kwargs)
#     309     if not download_if_necessary:
#     310         raise ValueError("Model '%s' is not downloaded" % name)
# --> 312     download_zoo_model(name)
#     314 if install_requirements:
#     315     model.install_requirements(error_level=error_level)
#
# File ~/miniconda3/envs/cvmgr/lib/python3.10/site-packages/fiftyone/zoo/models/__init__.py:179, in download_zoo_model(name_or_url, model_name, overwrite)
#     177     logger.info("Model '%s' is already downloaded", model.name)
#     178 elif model.manager is not None:
# --> 179     model.manager.download_model(model_path, force=overwrite)
#     180 else:
#     181     logger.info(
#     182         "Model '%s' downloading is not managed by FiftyOne",
#     183         model.name,
#     184     )
#
# File ~/miniconda3/envs/cvmgr/lib/python3.10/site-packages/eta/core/models.py:1789, in ModelManager.download_model(self, model_path, force)
#    1783     raise ModelError(
#    1784         "Model downloading is currently disabled. Modify your ETA "
#    1785         "config to change this setting."
#    1786     )
#    1788 etau.ensure_basedir(model_path)
# -> 1789 self._download_model(model_path)
#    1791 if self.config.extract_archive:
#    1792     if self.config.delete_archive is not None:
#
# File ~/miniconda3/envs/cvmgr/lib/python3.10/site-packages/fiftyone/zoo/models/__init__.py:547, in RemoteModelManager._download_model(self, model_path)
#     546 def _download_model(self, model_path):
# --> 547     _download_remote_model(self.config.model_name, model_path)
#
# File ~/miniconda3/envs/cvmgr/lib/python3.10/site-packages/fiftyone/zoo/models/__init__.py:553, in _download_remote_model(model_name, model_path)
#     550 def _download_remote_model(model_name, model_path):
#     551     model_dir = os.path.dirname(model_path)
# --> 553     module = _import_zoo_module(model_dir)
#     554     if not hasattr(module, "download_model"):
#     555         raise ValueError(
#     556             f"Module {model_dir} has no 'download_model()' method"
#     557         )
#
# File ~/miniconda3/envs/cvmgr/lib/python3.10/site-packages/fiftyone/zoo/models/__init__.py:598, in _import_zoo_module(model_dir)
#     596 module = importlib.util.module_from_spec(spec)
#     597 sys.modules[module.__name__] = module
# --> 598 spec.loader.exec_module(module)
#     599 return module
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/fiftyone/__models__/sam3/__init__.py:7
#       4 from huggingface_hub import snapshot_download
#       5 from fiftyone.operators import types
# ----> 7 from .zoo import Sam3Model
#       9 logger = logging.getLogger(__name__)
#      12 def download_model(model_name, model_path):
#
# File ~/fiftyone/__models__/sam3/zoo.py:22
#      20 from fiftyone.core.models import SupportsGetItem, TorchModelMixin
#      21 from fiftyone.core.labels import Detection, Detections, Keypoint, Keypoints
# ---> 22 from fiftyone.utils.torch import GetItem
#      24 logger = logging.getLogger(__name__)
#      27 # Operations registry
#
# File ~/miniconda3/envs/cvmgr/lib/python3.10/site-packages/fiftyone/utils/torch.py:44
#      41 import torch.distributed as dist
#      43 import torchvision
# ---> 44 from torchvision.models.feature_extraction import create_feature_extractor
#      45 from torchvision.transforms import functional as F
#      48 logger = logging.getLogger(__name__)
#
# ModuleNotFoundError: No module named 'torchvision.models'

# %% [markdown]
# ## 3. Visual Embeddings
#
# Extract 1024-dim embeddings for similarity search:

# %%
# Compute embeddings
model.pooling_strategy = "max"  # or "mean", "cls"

dataset.compute_embeddings(
    model,
    embeddings_field="sam_embeddings",
    batch_size=16,
    num_workers=8
)

print("✅ Embeddings computed")

# %%
# Visualize with UMAP
fob.compute_visualization(
    dataset,
    method="umap",
    brain_key="sam_viz",
    embeddings="sam_embeddings",
    num_dims=2
)

print("✅ UMAP visualization ready")

# %% [markdown]
# ## 4. Concept Segmentation
#
# Find ALL instances matching text concepts:

# %%
# Single concept
model.operation = "concept_segmentation"
model.prompt = "person"
model.threshold = 0.5
model.mask_threshold = 0.5

dataset.apply_model(
    model,
    label_field="people",
    batch_size=16,
    num_workers=8
)

# %%
# Multiple concepts (runs once per concept - slower!)
# 7 concepts = 7x inference passes
model.prompt = [
    "bird", "human", "land vehicle", "air vehicle",
    "animal", "food", "furniture"
]

dataset.apply_model(
    model,
    label_field="multi_concept",
    batch_size=16,
    num_workers=8
)

# %% [markdown]
# ## 5. Visual Segmentation
#
# Refine existing detections into precise masks:

# %%
model.operation = "visual_segmentation"

dataset.apply_model(
    model,
    label_field="visual_masks",
    prompt_field="ground_truth",  # Use existing detections as prompts
    batch_size=16,
    num_workers=8
)

# %% [markdown]
# ## 6. Automatic Segmentation
#
# Segment everything with quality filtering:

# %%
model.operation = "automatic_segmentation"
model.auto_kwargs = {
    "points_per_side": 16,       # Grid: 16x16 = 256 points
    "points_per_batch": 256,     # Batch size
    "quality_threshold": 0.8,    # Keep high quality only
    "iou_threshold": 0.85,       # Remove duplicates
    "max_masks": 100             # Top 100 masks
}

# Run on subset (automatic is slow)
dataset.take(10).apply_model(
    model,
    label_field="auto_masks",
    batch_size=16,
    num_workers=8
)

# %% [markdown]
# ## 7. Launch FiftyOne App

# %%
session = fo.launch_app(dataset)

# In Colab, use:
# session = fo.launch_app(dataset, auto=True)
# print(session.url)

# %% [markdown]
# ## 8. Explore Results

# %%
from fiftyone import ViewField as F

# Filter by label
people = dataset.filter_labels("people", F("label") == "person")
print(f"Found people in {len(people)} samples")

# Filter by confidence
high_conf = dataset.filter_labels("multi_concept", F("confidence") > 0.8)
print(f"High confidence detections: {len(high_conf.exists('multi_concept'))}")

# Similarity search
fob.compute_similarity(dataset, embeddings="sam_embeddings")
query = dataset.first()
similar = dataset.sort_by_similarity(query, k=10)
print(f"Found {len(similar)} similar images")

# %% [markdown]
# ## Summary
#
# You've now:
# - ✅ Computed visual embeddings for similarity search
# - ✅ Found objects using text prompts (concept segmentation)
# - ✅ Refined detections with precise masks (visual segmentation)
# - ✅ Generated all possible masks (automatic segmentation)
#
# **Next Steps:**
# - Try different prompts for concept segmentation
# - Adjust thresholds for more/fewer detections
# - Experiment with automatic segmentation parameters
#
# **Documentation:** https://github.com/harpreetsahota204/sam3_images
