# %% [markdown]
# # update needed, since the paths are now all in the yaml

# %% [markdown]
# # put the paths and variables for roboflow here

# %%
#ebi rundgang 

ROBOFLOW_API_KEY="ADColuoy8Ft64vwHwB5u"
ROBOFLOW_WORKSPACE="rundgang"
ROBOFLOW_PROJECT="ebi-rundgang-z1fgl"
DATASET_VERSION=1
DATASET_TYPE="test"
DATASET_PARENT_DIR="/mnt/EBI-SHARE/06_Data/labelstudio/datasets"
FORMAT="yolov5"

destination_path=f"{DATASET_PARENT_DIR}/{DATASET_TYPE}/{ROBOFLOW_PROJECT}-{DATASET_VERSION}-{FORMAT}"
labelstudio_path=f"/data/local-files/?d=datasets/{DATASET_TYPE}/{ROBOFLOW_PROJECT}-{DATASET_VERSION}-{FORMAT}"

# %%
#windows

ROBOFLOW_API_KEY="AgfWlgODe2lXi5Nh5VTu"
ROBOFLOW_WORKSPACE="tafeln"
ROBOFLOW_PROJECT="fensterfurmodel"
DATASET_VERSION=5
DATASET_TYPE="windows"
DATASET_PARENT_DIR="/mnt/EBI-SHARE/06_Data/labelstudio/datasets"


destination_path=f"{DATASET_PARENT_DIR}/{DATASET_TYPE}/{ROBOFLOW_PROJECT}-{DATASET_VERSION}"

# %%
#lights

ROBOFLOW_API_KEY="AgfWlgODe2lXi5Nh5VTu"
ROBOFLOW_WORKSPACE="tree-detection-zocbs"
ROBOFLOW_PROJECT="light_detect_3"
DATASET_VERSION=2
DATASET_TYPE="lights"
DATASET_PARENT_DIR="/mnt/EBI-SHARE/06_Data/labelstudio/datasets"


destination_path=f"{DATASET_PARENT_DIR}/{DATASET_TYPE}/{ROBOFLOW_PROJECT}-{DATASET_VERSION}"

# %%
import roboflow

rf = roboflow.Roboflow(api_key=ROBOFLOW_API_KEY)

# get a workspace
workspace = rf.workspace("rundgang")

# Upload data set to a new/existing project
workspace.upload_dataset(
    "/mnt/EBI-SHARE/06_Data/labelstudio/datasets/test/rundgang", # This is your dataset path
    "rundgang-chairs", # This will either create or get a dataset with the given ID
    num_workers=10,
    project_license="MIT",
    project_type="object-detection",
    batch_name=None,
    num_retries=0
)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Uploading to existing project rundgang/rundgang-chairs
# [UPLOADED] /mnt/EBI-SHARE/06_Data/labelstudio/datasets/test/rundgang/images/test/000000005142.jpg (pttCBWs4czNUrLVPOINH) [1.2s] / annotations = OK [0.6s]
# [UPLOADED] /mnt/EBI-SHARE/06_Data/labelstudio/datasets/test/rundgang/images/test/000000004567.jpg (J9O2zxwlGCd2nmY17lIL) [1.3s] / annotations = OK [0.6s]
# [UPLOADED] /mnt/EBI-SHARE/06_Data/labelstudio/datasets/test/rundgang/images/test/000000002477.jpg (T8tURKJMVb416NcAwWnp) [1.3s] / annotations = OK [0.6s]
# [UPLOADED] /mnt/EBI-SHARE/06_Data/labelstudio/datasets/test/rundgang/images/test/000000004092.jpg (PMhhSKTW7kPfPUp1jNpu) [1.4s] / annotations = OK [0.6s]
# [UPLOADED] /mnt/EBI-SHARE/06_Data/labelstudio/datasets/test/rundgang/images/test/000000000110.jpg (KlkUOdUFd1wASW1KaLf8) [1.5s] / annotations = OK [0.7s]
# ...

# %% [markdown]
# # ab hier gebe ich auf

# %% [markdown]
# # convert from data.yaml to classes.txt

# %%
print(destination_path)
# Out:
# /mnt/EBI-SHARE/06_Data/labelstudio/datasets/evaluation/room312_and_leuthener-2
