# %% [markdown]
# # put the paths and variables for roboflow here

# %%
ROBOFLOW_API_KEY="AgfWlgODe2lXi5Nh5VTu"
ROBOFLOW_WORKSPACE="made-srcnb"
ROBOFLOW_PROJECT="room312_and_leuthener"
DATASET_VERSION=2
DATASET_TYPE="evaluation"

# %%
import shutil
import subprocess
from roboflow import Roboflow


rf = Roboflow(api_key=ROBOFLOW_API_KEY)
project = rf.workspace(ROBOFLOW_WORKSPACE).project(ROBOFLOW_PROJECT)
version = project.version(DATASET_VERSION)
dataset = version.download("yolov8")

source_path=f"./{ROBOFLOW_PROJECT}-{DATASET_VERSION}"
destination_path=f"./datasets/{DATASET_TYPE}/{ROBOFLOW_PROJECT}-{DATASET_VERSION}"
shutil.copytree(source_path, destination_path, dirs_exist_ok=True)
shutil.rmtree(source_path)

subprocess.run(["chmod", "-R", "777", f"{destination_path}"])

print(f"dataset copied to {destination_path} and permissions set to 777")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in room312_and_leuthener-2 to yolov8:: 100%|██████████| 3836/3836 [00:01<00:00, 3611.32it/s]
# Extracting Dataset Version Zip to room312_and_leuthener-2 in yolov8:: 100%|██████████| 86/86 [00:00<00:00, 9160.89it/s]
# roboflow dataset downloaded
# dataset moved from ./room312_and_leuthener-2 to ./datasets/evaluation/room312_and_leuthener-2
# CompletedProcess(args=['chmod', '-R', '777', './datasets/evaluation/room312_and_leuthener-2'], returncode=0)
